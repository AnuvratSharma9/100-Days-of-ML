# %% [markdown]
# # Normalisation

# %% [markdown]
# ### Normalization is a way to rescale your data so that all feature values fit within a specific range, usually 0 to 1.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\DELL\Downloads\wine_data.csv",header=None,usecols=[0,1,2])
df.columns=['Class label','Alcohol','Malic Acid']
df
# Out:
#      Class label  Alcohol  Malic Acid
# 0              1    14.23        1.71
# 1              1    13.20        1.78
# 2              1    13.16        2.36
# 3              1    14.37        1.95
# 4              1    13.24        2.59
# ..           ...      ...         ...
# 173            3    13.71        5.65
# 174            3    13.40        3.91
# 175            3    13.27        4.28
# 176            3    13.17        2.59
# 177            3    14.13        4.10
#
# [178 rows x 3 columns]

# %%
sns.kdeplot(df['Alcohol'])
# Out:
# <Axes: xlabel='Alcohol', ylabel='Density'>

# %%
color_dict={1:'red',2:'blue',3:'green'}
sns.scatterplot(data=df,x='Alcohol',y='Malic Acid',hue='Class label',palette= color_dict)
# Out:
# <Axes: xlabel='Alcohol', ylabel='Malic Acid'>

# %% [markdown]
# # Splitting your dataset

# %%
from sklearn.model_selection import train_test_split
X=df.drop('Class label',axis=1)
y=df['Class label']
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=0)
X_test.shape
# Out:
# (54, 2)

# %% [markdown]
# # Min Max Scaler

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
scaler.fit(X_train)
X_train_scale=scaler.transform(X_train)
X_test_scale=scaler.transform(X_test)
X_train_scale
# Out:
# array([[0.72043011, 0.20378151],
#        [0.31989247, 0.08403361],
#        [0.60215054, 0.71218487],
#        [0.57258065, 0.56302521],
#        [0.76075269, 0.1302521 ],
#        [0.48924731, 0.5       ],
#        [0.75537634, 0.67857143],
#        [0.61021505, 0.17436975],
#        [0.54301075, 0.62394958],
#        [0.39784946, 0.07352941],
#        [0.33870968, 0.1092437 ],
#        [0.46774194, 0.53361345],
#        [0.5188172 , 0.53781513],
#        [0.70967742, 0.07563025],
#        [0.57258065, 0.30882353],
#        [0.36021505, 0.0105042 ],
#        [0.38709677, 0.13235294],
#        [0.20967742, 0.25840336],
#        [0.59408602, 0.64915966],
#        [0.82526882, 0.26680672],
#        [0.15591398, 0.09663866],
#        [0.52688172, 0.16386555],
#        [0.46774194, 0.31512605],
#        [0.65860215, 0.16386555],
#        [0.1155914 , 0.5987395 ],
#        [0.27956989, 0.26680672],
#        [0.21236559, 0.12184874],
#        [0.65053763, 0.59033613],
# ...

# %%
X_train_scale=pd.DataFrame(X_train_scale,columns=X_train.columns)
X_test_scale=pd.DataFrame(X_test_scale,columns=X_test.columns)

# %%
np.round(X_train_scale.describe())
# Out:
#        Alcohol  Malic Acid
# count    124.0       124.0
# mean       1.0         0.0
# std        0.0         0.0
# min        0.0         0.0
# 25%        0.0         0.0
# 50%        1.0         0.0
# 75%        1.0         0.0
# max        1.0         1.0

# %%
np.round(X_train.describe())
# Out:
#        Alcohol  Malic Acid
# count    124.0       124.0
# mean      13.0         2.0
# std        1.0         1.0
# min       11.0         1.0
# 25%       12.0         2.0
# 50%       13.0         2.0
# 75%       14.0         3.0
# max       15.0         6.0

# %%
ax1= sns.scatterplot(data=X_train, x='Alcohol',y='Malic Acid')
ax1.set_title('Before Scaling')

# %%
ax2= sns.scatterplot(data=X_train_scale,x='Alcohol',y='Malic Acid', color= 'red')
plt.title('After Scaling')
# Out:
# Text(0.5, 1.0, 'After Scaling')
